# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DatosSTAT.csv", index_col=0, sep=',', encoding='latin-1', on_bad_lines='skip')

# %%
df.columns
# Out:
# Index(['N-C', 'Recibe', 'Resuelve', 'Remota', 'Fecha llamada', 'Hora llamada',
#        ' Cod Cliente', 'Nombre Cliente', 'Cod Equipo', 'Nombre Equipo',
#        'Serie', 'ID SAP', 'Tipo de Problema', 'Subtipo de Problema',
#        'Comentario', 'Fecha inicio actividad', 'Hora inicio actividad',
#        'Fecha fin actividad', 'Hora fin actividad', 'Tiempo efectivo',
#        'Resolución', 'Resuelve.1', 'Cerrada', 'Procesada'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Remota  ID SAP  Tiempo efectivo  Resuelve.1      Cerrada
# count  1890.000000  1890.0      1890.000000         0.0  1890.000000
# mean      0.326455     0.0         2.556767         NaN     0.612169
# std       0.469040     0.0         4.118009         NaN     0.487385
# min       0.000000     0.0         0.000000         NaN     0.000000
# 25%       0.000000     0.0         0.500000         NaN     0.000000
# 50%       0.000000     0.0         1.250000         NaN     1.000000
# 75%       1.000000     0.0         3.500000         NaN     1.000000
# max       1.000000     0.0       130.000000         NaN     1.000000

# %%
df.count()
# Out:
# N-C                       1890
# Recibe                    1890
# Resuelve                  1890
# Remota                    1890
# Fecha llamada             1890
# Hora llamada              1890
#  Cod Cliente              1890
# Nombre Cliente            1890
# Cod Equipo                1629
# Nombre Equipo             1626
# Serie                     1607
# ID SAP                    1890
# Tipo de Problema          1870
# Subtipo de Problema       1879
# Comentario                1889
# Fecha inicio actividad    1890
# Hora inicio actividad     1890
# Fecha fin actividad       1890
# Hora fin actividad        1890
# Tiempo efectivo           1890
# Resolución                1867
# Resuelve.1                   0
# Cerrada                   1890
# Procesada                 1890
# dtype: int64

# %%
df.head()
# Out:
#       N-C            Recibe         Resuelve  Remota Fecha llamada  \
# Num
# 14241   N  Julian Pastoriza    Lucas Saldaña       0    2024-04-09
# 14235   N      Matias Davyt     Matias Davyt       1    2024-04-09
# 14233   N   Noemi Rodriguez  Noemi Rodriguez       0    2024-04-09
# 14236   N   Noemi Rodriguez  Noemi Rodriguez       0    2024-04-09
# 14227   N    Martin Machado   Martin Machado       0    2024-04-09
#
#       Hora llamada  Cod Cliente  \
# Num
# 14241     17:27:00        C0223
# 14235     15:50:00        C0012
# 14233     14:00:00        C0467
# 14236     11:30:00        C0467
# 14227     09:00:00        C0091
#
#                                           Nombre Cliente  Cod Equipo  \
# Num
# 14241                                        CABINSUR SA         NaN
# 14235  Dirección Nacional de Sanidad de las Fuerzas A...  BK37100344
# 14233                                Juan B. Canali S.A.   PER055300
# ...

# %%
conteo_por_cliente = df.groupby('Nombre Cliente')['Resuelve'].count()
print(conteo_por_cliente)
# Out:
# Nombre Cliente
# AMEDRIN IAMPP                                          8
# AMSJ IAMPP                                            24
# ASSE - Centro Aux. Bella Unión UE34                    3
# ASSE - Centro Hospitalario Pereira Rossell UE 004     27
# ASSE - Hospital Dr. Gustavo Saint Bois U.E. 012        1
#                                                     ...
# Servicio Médico Integral - SMI                        16
# Servicio Nacional de Sangre                           37
# Siembrasur S.A.                                      154
# Sociedad Médica Quirúrgica de Salto                   20
# UNIVERSAL SPS                                          2
# Name: Resuelve, Length: 98, dtype: int64

# %%
conteo_por_año = df.groupby('Fecha llamada')['Nombre Cliente'].count()
conteo_por_año
# Out:
# Fecha llamada
# 2023-12-19     5
# 2023-12-20    33
# 2023-12-21    24
# 2023-12-22    42
# 2023-12-23     3
#               ..
# 2024-04-05    12
# 2024-04-06     2
# 2024-04-07     2
# 2024-04-08    14
# 2024-04-09     5
# Name: Nombre Cliente, Length: 94, dtype: int64

# %%
# Graficar el resultado
plt.figure(figsize=(10, 6))
plt.scatter(conteo_por_año.index, conteo_por_año.values, color='green')
plt.title('Cantidad de ND por fecha', fontsize=16)
plt.xlabel('Año', fontsize=14)
plt.ylabel('Cantidad de ND', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Histograma

plt.figure(figsize=(10, 6))
plt.hist(df['Fecha llamada'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribución de ND por Fecha', fontsize=16)
plt.xlabel('Año', fontsize=14)
plt.ylabel('Cantidad de ND', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df['Fecha llamada new'] = df['Fecha llamada'].str.strip()

# Convertir la columna 'date_added' a tipo datetime especificando el formato correcto
df['Fecha llamada new'] = pd.to_datetime(df['Fecha llamada new'], format='%Y-%m-%d')

df['Fecha llamada new'] = df['Fecha llamada new'].dt.strftime('%Y%m%d')

# Imprimir el DataFrame resultante
df.tail()
# Out:
#               N-C           Recibe        Resuelve  Remota Fecha llamada  \
# Num
# 12235           N   Santiago Lopez  Martin Machado       0    2023-12-19
# 12415  0000012235   Santiago Lopez  Martin Machado       0    2023-12-19
# 12250           N   Carolina Proto  Carolina Proto       1    2023-12-19
# 12282  0000012250   Carolina Proto  Carolina Proto       1    2023-12-19
# 12228           N  Guillermo Tomas  Santiago Lopez       0    2023-12-19
#
#       Hora llamada  Cod Cliente  \
# Num
# 12235     18:42:00        C0001
# 12415     18:42:00        C0001
# 12250     17:00:00        C0143
# 12282     17:00:00        C0143
# 12228     15:15:00        C0001
#
#                                        Nombre Cliente Cod Equipo  \
# Num
# 12235  Asociación Española Primera de Socorros Mutuos    BR91587
# 12415  Asociación Española Primera de Socorros Mutuos    BR91587
# 12250             Sociedad Médica Quirúrgica de Salto    DE81200
# ...

# %%
tipos_nd = df.groupby('Subtipo de Problema')['Nombre Cliente'].count()
tipos_nd
# Out:
# Subtipo de Problema
# APP       7
# CAP      34
# CON       6
# DES      19
# EU       11
# IAT     545
# IMP       9
# INS      51
# MC      435
# MPA     175
# MPM      20
# MPS      24
# MRQ      10
# OTRO    254
# PC       18
# PM        2
# PRO       5
# QC      118
# SW       24
# VAL      42
# VER      70
# Name: Nombre Cliente, dtype: int64

# %%
# Graficar el resultado
plt.figure(figsize=(10, 6))
plt.bar(tipos_nd.index, tipos_nd.values, color='green')
plt.title('Cantidad de ND por Tipo', fontsize=16)
plt.xlabel('Tipos', fontsize=14)
plt.ylabel('Cantidad de ND', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
conteo_por_año = df.groupby('Fecha llamada new')['Nombre Cliente'].count()
conteo_por_año
# Out:
# Fecha llamada new
# 20231219     5
# 20231220    33
# 20231221    24
# 20231222    42
# 20231223     3
#             ..
# 20240405    12
# 20240406     2
# 20240407     2
# 20240408    14
# 20240409     5
# Name: Nombre Cliente, Length: 94, dtype: int64

# %%
df['Año'] = pd.to_datetime(df['Fecha llamada new'], errors='coerce')
df['Año'] = df['Año'].dt.strftime('%Y')

# %%
conteo_por_año = df.groupby('Año')['Nombre Cliente'].count()
conteo_por_año
# Out:
# Año
# 2023     218
# 2024    1672
# Name: Nombre Cliente, dtype: int64

# %%
df['mes'] = pd.to_datetime(df['Fecha llamada new'], errors='coerce')
df['mes'] = df['mes'].dt.strftime('%m')
df
# Out:
#               N-C            Recibe         Resuelve  Remota Fecha llamada  \
# Num
# 14241           N  Julian Pastoriza    Lucas Saldaña       0    2024-04-09
# 14235           N      Matias Davyt     Matias Davyt       1    2024-04-09
# 14233           N   Noemi Rodriguez  Noemi Rodriguez       0    2024-04-09
# 14236           N   Noemi Rodriguez  Noemi Rodriguez       0    2024-04-09
# 14227           N    Martin Machado   Martin Machado       0    2024-04-09
# ...           ...               ...              ...     ...           ...
# 12235           N    Santiago Lopez   Martin Machado       0    2023-12-19
# 12415  0000012235    Santiago Lopez   Martin Machado       0    2023-12-19
# 12250           N    Carolina Proto   Carolina Proto       1    2023-12-19
# 12282  0000012250    Carolina Proto   Carolina Proto       1    2023-12-19
# 12228           N   Guillermo Tomas   Santiago Lopez       0    2023-12-19
#
#       Hora llamada  Cod Cliente  \
# Num
# ...

# %%
conteo_por_año_mes = df.groupby('mes')['Nombre Cliente'].count()
conteo_por_año_mes
# Out:
# mes
# 01    570
# 02    492
# 03    501
# 04    109
# 12    218
# Name: Nombre Cliente, dtype: int64

# %%
# Graficar el resultado
plt.figure(figsize=(10, 6))
plt.bar(conteo_por_año_mes.index, conteo_por_año_mes.values, color='green')
plt.title('Cantidad de ND por Año', fontsize=16)
plt.xlabel('Tipos', fontsize=14)
plt.ylabel('Cantidad de ND', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
conteo_por_resuelve = df.groupby('Resuelve')['Nombre Cliente'].count()
conteo_por_resuelve = conteo_por_resuelve.sort_values(ascending = False)
conteo_por_resuelve = conteo_por_resuelve[conteo_por_resuelve > 2]
conteo_por_resuelve
# Out:
# Resuelve
# Carolina Proto        403
# Marco Alpuin          230
# Fernando Conlazo      149
# Martin Machado        126
# Matias Davyt          126
# Guillermo Tomas       113
# Maximiliano Vespa     113
# Santiago Lopez         94
# Luis Oropeza           90
# Marcela Castro         88
# Fernando Rodriguez     80
# Lucas Saldaña          80
# Jovan Klaric           74
# Renato Sosa            67
# Danilo Caballero       28
# Noemi Rodriguez        19
# Valeria Cal             5
# Name: Nombre Cliente, dtype: int64

# %%
# Graficar el resultado
plt.figure(figsize=(10, 6))
plt.bar(conteo_por_resuelve.index, conteo_por_resuelve.values, color='green')
plt.title('Cantidad de ND resueltas por STAT', fontsize=16)
plt.xlabel('Personal', fontsize=14)
plt.ylabel('Cantidad de ND', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
conteo_por_tipo_problema = df.groupby('Tipo de Problema')['Nombre Cliente'].count()
conteo_por_tipo_problema
# Out:
# Tipo de Problema
# AQC    115
# AT     682
# SI     108
# ST     958
# STA      7
# Name: Nombre Cliente, dtype: int64

# %%
# Graficar el resultado
plt.figure(figsize=(10, 6))
plt.bar(conteo_por_tipo_problema.index, conteo_por_tipo_problema.values, color='blue')
plt.title('Cantidad de ND resueltas por Tipo Problema', fontsize=16)
plt.xlabel('Tipo ', fontsize=14)
plt.ylabel('Cantidad de ND', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
print(df.dtypes)
# Out:
# N-C                        object
# Recibe                     object
# Resuelve                   object
# Remota                      int64
# Fecha llamada              object
# Hora llamada               object
#  Cod Cliente               object
# Nombre Cliente             object
# Cod Equipo                 object
# Nombre Equipo              object
# Serie                      object
# ID SAP                      int64
# Tipo de Problema           object
# Subtipo de Problema        object
# Comentario                 object
# Fecha inicio actividad     object
# Hora inicio actividad      object
# Fecha fin actividad        object
# Hora fin actividad         object
# Tiempo efectivo           float64
# Resolución                 object
# Resuelve.1                float64
# Cerrada                     int64
# Procesada                  object
# Fecha llamada new          object
# Año                        object
# mes                        object
# dtype: object

# %%
conteo_horas_por_cliente = df.groupby('Nombre Cliente')['Tiempo efectivo'].sum()
conteo_horas_por_cliente = conteo_horas_por_cliente.sort_values(ascending = False)
conteo_horas_por_cliente
# Out:
# Nombre Cliente
# CABINSUR SA                                      1065.50
# Siembrasur S.A.                                   441.40
# ASSE - Hospital de Florida UE 021                 271.25
# Fertilab SA                                       219.43
# Laboratorio G. Martínez Prado S.A.                207.56
#                                                   ...
# Lab. IVD Uruguay S.A.                               0.50
# Corporación Médica de Paysandú IAMPP (COMEPA)       0.10
# MALTERIA ORIENTAL S.A.                              0.00
# Cooperativa Agraria de Dolores SRL                  0.00
# BENTEN BIOTECH SRL                                  0.00
# Name: Tiempo efectivo, Length: 98, dtype: float64

# %%
# Graficar el resultado para el TOP 10 de Mayor tiempo
conteo = conteo_horas_por_cliente[:5]
plt.figure(figsize=(10, 6))
plt.bar(conteo.index, conteo.values, color='limegreen')
plt.title('Top 5 Cantidad de horas dedicas por cliente', fontsize=16)
plt.xlabel('Cliente', fontsize=14)
plt.ylabel('Horas', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
conteo_horas_por_equipo = df.groupby('Nombre Equipo')['Tiempo efectivo'].sum()
conteo_horas_por_equipo = conteo_horas_por_equipo.sort_values(ascending = False)
conteo_horas_por_equipo
# Out:
# Nombre Equipo
# Chorus Trio                                                            450.31
# D10 HbA1c Analyzer                                                     345.89
# QUANTA-Lyser 3000 ELISA/IFA + Incubator  | Werfen                      341.30
# Walkaway 40 PLUS | Equipo | Beckman Coulter                            331.99
# Bio-Flash SYSTEM | Equipo | Werfen                                     312.39
#                                                                         ...
# ID-Centrifuge 24S |Equipo |Galenica                                      0.45
# LP35 MICROPLATE WASHER                                                   0.25
# Inframatic 9500 NIR Grain Analyzer | Equipo | Perkin Elmer (Perten)      0.00
# NGC Quest 10 Chromatography System | Bio-Rad                             0.00
# Falling Number 1310 230V 50-60Hz | Equipo | Perkin Elmer                 0.00
# Name: Tiempo efectivo, Length: 79, dtype: float64

# %%
# Graficar el resultado para el TOP 5
# Seleccionar un colormap
colormap = plt.cm.tab10
# Número de colores que deseas generar
numero_colores = 5
# Generar una lista de colores muestreando el colormap
lista_colores = [colormap(i) for i in range(numero_colores)]
conteo = conteo_horas_por_equipo[:5]
plt.figure(figsize=(10, 6))
plt.bar(conteo.index, conteo.values, color=lista_colores)
plt.title('Top 5 Cantidad de horas dedicas por Equipos', fontsize=16)
plt.xlabel('Equipo', fontsize=14)
plt.ylabel('Horas', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df_filtrado = df[df['Resuelve'] == "Lucas Saldaña"]
conte_horas_propias_cliente = df_filtrado.groupby('Nombre Equipo')['Tiempo efectivo'].sum()
conte_horas_propias_cliente = conte_horas_propias_cliente.sort_values(ascending = False)
conte_horas_propias_cliente
# Out:
# Nombre Equipo
# ISYS Multi-Discipline Automated System  | IDS           23.25
# Bio-Flash SYSTEM | Equipo | Werfen                      14.69
# INGENIUS ELITE | Equipo | Elitech Group                  6.10
# SPIFE Touch (230 Vac, 50/60 Hz) |Helena Laboratories     4.95
# GSP® Instrument |Equipo | Revvity                        3.00
# V8 Nexus CE Analyzer (115/230V) |Helena Laboratories     3.00
# D10 HbA1c Analyzer                                       1.68
# Optilite | Binding Site                                  1.55
# C1000 TOUCH THERMAL CYCLER | Equipo | Bio-Rad            1.50
# Saxo ID-Reader |Equipo |Galenica                         1.50
# IH-500 |Equipo  |Bio Rad DiaMed GMBH                     1.01
# NE-32 | Equipo | MGI                                     1.00
# Walkaway 96 | Equipo | Beckman Coulter                   1.00
# WalkAway 96 PLUS | Equipo | Beckman Coulter              0.50
# Name: Tiempo efectivo, dtype: float64
